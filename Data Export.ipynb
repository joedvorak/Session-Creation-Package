# %% [markdown]
# # Data export

# %%
df_oral_with_hybrid = pd.read_parquet("presentations_with_embeddings.parquet")
print(f"Loaded {len(df_oral_with_hybrid)} presentations with embeddings from parquet file.")

# %%
import pandas as pd

df_oral_with_hybrid= pd.read_parquet('df_no_abstractAIM26.parquet')

# %%
df_oral_with_hybrid.to_excel('df_no_abstractAIM26.xlsx', index=False)
